# %% [markdown]
# *Mel Kon* <br>
# *Gnoeulelien Tako*

# %% [markdown]
# Data collected from https://databank.worldbank.org/reports.aspx?source=2&series=DT.ODA.ALLD.CD&country=AFG#

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('failedstates.csv',header=None)


dfx
mapd = df.T
mapd.iloc[0].iloc[0]
p = mapd.reset_index()

pdf2 = p.apply(pd.to_numeric, errors='coerce').fillna(p)
#f = df[1:]
pdf2
# df.reset_index()
x = df.T

new_header = x.iloc[0] 
x = x[1:] 
x.columns = new_header 
df2 = x.apply(pd.to_numeric, errors='coerce').fillna(x)
df2.plot()
# Out:
# <AxesSubplot:>

# %% [raw]
# From the Data there is not much we are able to tell about the correlation of aid and failed states. We believe we need to collect more data and use a different approach
